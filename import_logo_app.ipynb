# %%
from flask import Flask, request

app = Flask(__name__)

@app.route('/', methods=['GET', 'POST'])
def upload_file():
    if request.method == 'POST':
        file = request.files['imageFile']
        if file:
            filename = file.filename
            file.save('uploads/' + filename)
            return f"""{filename} uploaded successfully!\n
            Takes 10 Seconds to upload your image\n
            After 10 Seconds choose another logo size to update bow_model."""
        
        
    return '''
    <!doctype html>
    <html>
    <head>
        <title>Image Upload</title>
    </head>
    <body>
        <form method="post" enctype="multipart/form-data">
            <input type="file" name="imageFile">
            <input type="submit" value="Upload">
        </form>
    </body>
    </html>
    '''

#if __name__ == '__main__':
    #app.run()

# %%
app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.66:5000
# Press CTRL+C to quit
# 192.168.1.66 - - [17/May/2023 12:46:46] "GET / HTTP/1.1" 200 -
# 192.168.1.66 - - [17/May/2023 12:47:11] "POST / HTTP/1.1" 200 -

# %%
http://192.168.1.66:5000/
